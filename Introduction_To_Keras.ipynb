# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushkubb/Deep_Learning_Tutorial/blob/master/Introduction_To_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras
# Its high level deep learning API build on top of Tensorflow
#
#
#
#
# *   Models
# *   Optimisers
# *   Loss
# *   Metrics
# *   Training Loops
# *   Callbacks - Early Stopping, Checkpoint, Tensorboard

# %% [markdown]
# ## Install required libraries

# %%
# !pip install tensorflow
# !pip install keras

# %%
# Dummy Dataset
import numpy as np

#Random Dataset
X_train=np.random.random((1000,20))
y_train=np.random.random((1000,1))


X_test=np.random.random((100,20))
y_test=np.random.random((100,1))

# %%
X_train.shape
# Out:
# (1000, 20)

# %%
y_train.shape
# Out:
# (1000, 1)

# %%
X_train[:2]
# Out:
# array([[0.9019279 , 0.28581917, 0.2074259 , 0.32852683, 0.69668506,
#         0.84518669, 0.01343615, 0.25339029, 0.23459386, 0.92978772,
#         0.68761961, 0.1555108 , 0.03325252, 0.91796813, 0.33350844,
#         0.37114953, 0.55822444, 0.39587352, 0.95076402, 0.92580398],
#        [0.17102643, 0.27957434, 0.50110504, 0.4237676 , 0.5431781 ,
#         0.44159357, 0.29715238, 0.14197837, 0.58077882, 0.34388181,
#         0.0815052 , 0.4612631 , 0.38853358, 0.38355938, 0.73629943,
#         0.04124775, 0.93181639, 0.55810755, 0.07600413, 0.00853581]])

# %%
y_train[:2]
# Out:
# array([[0.46577345],
#        [0.58779572]])

# %% [markdown]
# # Creating a Model
#
# ## Layers
#
#
# *   Dense Layer -> A layer of fully connected neurons
# *   Dropout
# *   Conv1D, conv2D,
# *   LSTM/GRU

# %%
# Imports
from keras.models import Sequential
from keras.layers import Dense

from keras import optimizers
from keras import metrics

# %%
# define the structure of the model
model=Sequential()

# Input Layer / Hidden Layer
model.add(Dense(10,activation='relu',input_dim=X_train.shape[1]))

# Second Layer
model.add(Dense(10,activation='relu'))

# Output Layer
model.add(Dense(1,activation='relu'))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 331 (1.29 KB)
#  Trainable params: 331 (1.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Configure the model for learning/training
# Loss, metrics, optimizer

model.compile(loss='mse',
              optimizer='adamax',)
              # metrics=['accuracy'])

# %%
# Training the model
model.fit(X_train,y_train,batch_size=500,epochs=30)
# Out:
# Epoch 1/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0798
# Epoch 2/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0799
# Epoch 3/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0811
# Epoch 4/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0811
# Epoch 5/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0813
# Epoch 6/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0794
# Epoch 7/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0812
# Epoch 8/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0807
# Epoch 9/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0805
# Epoch 10/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0800
# Epoch 11/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0801
# Epoch 12/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0805
# Epoch 13/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0795
# Epoch 14/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0802
# Epoch 15/30
# ...

# %%
y_pred=model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
